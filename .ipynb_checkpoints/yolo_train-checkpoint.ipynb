# %%
# ================================
# YOLO 초음파 종양 탐지
# ================================
from ultralytics import YOLO
import torch
import cv2
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

device = 0 if torch.cuda.is_available() else 'cpu'
print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
# Out:
# ✅ GPU: Tesla V100-SXM2-32GB

# %%
# ================================
# 모델 로드
# ================================
model = YOLO("/home/ubuntu/project/models/yolo/yolov8m.pt")
print("✅ YOLOv8m 로드 완료")

# 모델 정보 확인
print(model.info())
# Out:
# ✅ YOLOv8m 로드 완료
# YOLOv8m summary: 169 layers, 25,902,640 parameters, 0 gradients, 79.3 GFLOPs
# (169, 25902640, 0, 79.3204224)

# %%
# ================================
# 학습 (마운트 후 실행)
# ================================

# 마운트 후 주석 해제
'''
results = model.train(
    data="/home/ubuntu/project/src/ovarian_data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    device=0,
    project="/home/ubuntu/project/results",
    name="ovarian_yolo",
    patience=20,
    save=True,
    plots=True
)
'''

# 샘플로 테스트
results = model.predict(
    source="/home/ubuntu/project/data/sample/images/",
    device=0,
    conf=0.25,
    save=False
)
print(f"✅ 샘플 예측 완료: {len(results)}개")
# Out:
# image 1/10 /home/ubuntu/project/data/sample/images/sample_0.png: 640x640 (no detections), 9.6ms
# image 2/10 /home/ubuntu/project/data/sample/images/sample_1.png: 640x640 (no detections), 9.5ms
# image 3/10 /home/ubuntu/project/data/sample/images/sample_2.png: 640x640 (no detections), 9.5ms
# image 4/10 /home/ubuntu/project/data/sample/images/sample_3.png: 640x640 (no detections), 9.5ms
# image 5/10 /home/ubuntu/project/data/sample/images/sample_4.png: 640x640 (no detections), 9.5ms
# image 6/10 /home/ubuntu/project/data/sample/images/sample_5.png: 640x640 (no detections), 9.6ms
# image 7/10 /home/ubuntu/project/data/sample/images/sample_6.png: 640x640 (no detections), 9.5ms
# image 8/10 /home/ubuntu/project/data/sample/images/sample_7.png: 640x640 (no detections), 9.5ms
# image 9/10 /home/ubuntu/project/data/sample/images/sample_8.png: 640x640 (no detections), 9.5ms
# image 10/10 /home/ubuntu/project/data/sample/images/sample_9.png: 640x640 (no detections), 9.2ms
# ...

# %%
# ================================
# 결과 저장 (반출용)
# ================================
# 마운트 후 학습된 모델 저장
'''
import shutil
shutil.copy(
    "/home/ubuntu/project/results/ovarian_yolo/weights/best.pt",
    "/home/ubuntu/project/download/models/yolo_best.pt"
)
print("✅ 모델 반출 준비 완료")
'''
print("마운트 후 주석 해제해서 실행하세요!")
# Out:
# 마운트 후 주석 해제해서 실행하세요!
